# %%
from option_position_sizer import SizingInput, size_contracts, pretty_print

inp = SizingInput(
    account_size=5000, risk_pct=0.02,
    direction="put",
    entry_low=184.2, entry_high=184.5,  # your planned zone
    stop=185,
    delta=0.3, buffer=1.10,
    est_entry_premium=2.15,
    pct_drawdown_cap=0.10,               # 10% cap
)
res = size_contracts(inp)
pretty_print(res)
# Out:
# === Option Position Sizer ===
# Contracts (floor)        : 3
# Raw contracts            : 3.788
# Min entry (underlying)   : 184.3485  (to keep drawdown ≤ cap)
# Allowed $/share risk cap : $0.6515
# Planned zone within cap? : NO
# Per-contract loss @ stop : $26.40
# Est. entry premium       : $2.1500  (~$215.00 per contract)
# Drawdown @ stop          : 12.28% of premium
# Risk (% of account)      : 2.00% -> $100.00
# Entry zone (low → high)  : 184.2 → 184.5
# Stop (underlying)        : 185
# Delta (est.)             : 0.30
# Buffer                   : 1.10
# Per-share risk           : $0.8000
# Direction                : PUT
# Account size             : $5000.00
# Max allowed drawdown     : 10.00% of premium
# Min premium to meet cap  : $2.6400  (~$264.00/contract)
# Meets drawdown cap?      : NO
